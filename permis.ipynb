# %%
import pandas as pd
import numpy as np
from pathlib import Path

excel_data = pd.read_excel(Path("tableau-question.xlsx"))
excel_data = excel_data.drop(range(3,len(excel_data),4))
a = excel_data.set_index(["N°", "Type"])
a.index
# Out:
# MultiIndex([( '1\net 65',    'VI'),
#             (        nan,  'QSER'),
#             (        nan, '1er S'),
#             (          2,    'VE'),
#             (        nan,  'QSER'),
#             (        nan, '1er S'),
#             ( '3\net 67',    'VI'),
#             (        nan,  'QSER'),
#             (        nan, '1er S'),
#             ( '4\net 68',    'VE'),
#             ...
#             (        nan,     nan),
#             (         64,    'VE'),
#             (        nan,  'QSER'),
#             (        nan, '1er S'),
#             ('66\net 00',    'VE'),
#             (        nan,  'QSER'),
#             (        nan, '1er S'),
#             (         81,    'VI'),
#             (        nan,  'QSER'),
#             (        nan, '1er S')],
#            names=['N°', 'Type'], length=201)

# %%
a = excel_data.set_index(["N°", "Type"])
new_index = []
for (my_num, my_type) in a.index:
    if pd.notna(my_num):
        last_real_num = my_num
    if isinstance(last_real_num, str):
        last_real_num = last_real_num.replace("\net", "")
    else:
        last_real_num = str(last_real_num)
        # last_real_num = [int(_) for _ in last_real_num.split()]
    new_index.append((last_real_num, my_type))

# %%
new_multi_index = pd.MultiIndex.from_tuples(new_index, names=["num", "type"])
len(new_multi_index)
excel_data
# Out:
#            N°   Type                                           Question  \
# 0    1\net 65     VI  Montrez la commande de réglage de hauteur des ...
# 1         NaN   QSER      Pourquoi doit-on régler la hauteur des feux ?
# 2         NaN  1er S  Comment et pourquoi protéger une zone de dange...
# 4           2     VE  Montrez où s'effectue le remplissage du produi...
# 5         NaN   QSER  Pourquoi est-il préférable d'utiliser un liqui...
# ..        ...    ...                                                ...
# 261       NaN   QSER  Quelle est la principale conséquence d’un disp...
# 262       NaN  1er S  Qu’est ce qu’un défibrillateur automatisé exte...
# 264        81     VI  De quelle couleur est le voyant qui indique un...
# 265       NaN   QSER  Quel est le risque de circuler avec un frein d...
# 266       NaN  1er S  En général, en cas de panne ou d’accident, où ...
#
#                                                Réponse
# 0            Dispositif en général à gauche du volant.
# 1              Pour ne pas éblouir les autres usagers.
# 2    En délimitant clairement et largement la zone ...
# 4    Le candidat ouvre le capot et montre le bocal....
# 5                       Pour éviter le gel du liquide.
# ..                                                 ...
# 261  Une mauvaise visibilité due à l’impossibilité ...
# 262  C’est un appareil qui peut permettre de rétabl...
# 264                                                NaN
# 265            Une dégradation du système de freinage.
# 266  Le triangle de pré-signalisation doit être pla...
#
# [201 rows x 4 columns]

# %%
df = excel_data.set_index(new_multi_index).drop(["N°", "Type"], axis=1)

for q in df.loc['2']['Question']:
    print(q)
print('\nRéponses : ')
for q in df.loc['2']['Réponse']:
    print(q)
# Out:
# Montrez où s'effectue le remplissage du produit lave-glace.
# Pourquoi est-il préférable d'utiliser un liquide spécial en hiver ?
# Quels comportements adopter en cas de diffusion du signal d’alerte du Système d’Alerte et d’Information des Populations (SAIP) ?
#
# Réponses :
# Le candidat ouvre le capot et montre le bocal. Si le candidat a des difficultés pour ouvrir le capot, l'accompagnateur peut lui indiquer comment procéder.
# Pour éviter le gel du liquide.
# - Se mettre en sécurité.
# - S'informer grâce aux médias et sites internet des autorités dès que leur consultation est possible.
# - Respecter les consignes des autorités.

# %%
import pandas as pd
from pathlib import Path

excel_data = pd.read_excel(Path("tableau-question.xlsx"))
excel_data = excel_data.drop(range(3,len(excel_data),4))
a = excel_data.set_index(["N°", "Type"])
new_index = []
for (my_num, my_type) in a.index:
    if pd.notna(my_num):
        last_real_num = my_num
    if isinstance(last_real_num, str):
        last_real_num = last_real_num.replace("\net", "")
    else:
        last_real_num = str(last_real_num)
    new_index.append((last_real_num, my_type))
df = excel_data.set_index(new_multi_index).drop(["N°", "Type"], axis=1)

df.to_csv("toto.csv", sep=";", encoding='UTF-8')
